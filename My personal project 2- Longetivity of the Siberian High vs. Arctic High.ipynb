# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('city_temperature.csv')
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df[df['Country']=='China']['City'].unique()
# Out:
# array(['Beijing', 'Chengdu', 'Guangzhou', 'Shanghai', 'Shenyang'],
#       dtype=object)

# %%
dfshanghai = df[df['City']=='Shanghai']
dfshanghaihttp://localhost:8888/notebooks/Py_DS_ML_Bootcamp-master/Refactored_Py_DS_ML_Bootcamp-master/My%20personal%20project%202-%20Longetivity%20of%20the%20Siberian%20High%20vs.%20Arctic%20High.ipynb#
# Out:
#        Region Country State      City  Month  Day  Year  AvgTemperature
# 284726   Asia   China   NaN  Shanghai      1    1  1995            40.1
# 284727   Asia   China   NaN  Shanghai      1    2  1995            42.3
# 284728   Asia   China   NaN  Shanghai      1    3  1995            36.5
# 284729   Asia   China   NaN  Shanghai      1    4  1995            36.3
# 284730   Asia   China   NaN  Shanghai      1    5  1995            38.5
# ...       ...     ...   ...       ...    ...  ...   ...             ...
# 293987   Asia   China   NaN  Shanghai      5    9  2020            69.3
# 293988   Asia   China   NaN  Shanghai      5   10  2020            68.5
# 293989   Asia   China   NaN  Shanghai      5   11  2020            73.0
# 293990   Asia   China   NaN  Shanghai      5   12  2020            76.1
# 293991   Asia   China   NaN  Shanghai      5   13  2020            77.0
#
# [9266 rows x 8 columns]

# %%
dfbeijing = df[df['City']=='Beijing']
dfbeijing
# Out:
#        Region Country State     City  Month  Day  Year  AvgTemperature
# 256928   Asia   China   NaN  Beijing      1    1  1995            28.0
# 256929   Asia   China   NaN  Beijing      1    2  1995            29.0
# 256930   Asia   China   NaN  Beijing      1    3  1995            29.9
# 256931   Asia   China   NaN  Beijing      1    4  1995            34.5
# 256932   Asia   China   NaN  Beijing      1    5  1995            36.6
# ...       ...     ...   ...      ...    ...  ...   ...             ...
# 266189   Asia   China   NaN  Beijing      5    9  2020            60.6
# 266190   Asia   China   NaN  Beijing      5   10  2020            69.4
# 266191   Asia   China   NaN  Beijing      5   11  2020            73.0
# 266192   Asia   China   NaN  Beijing      5   12  2020            66.5
# 266193   Asia   China   NaN  Beijing      5   13  2020            72.5
#
# [9266 rows x 8 columns]

# %%
dfcolumbus = df[(df['City']=='Columbus') & (df['State']=='Ohio')]
dfcolumbus
# Out:
#                 Region Country State      City  Month  Day  Year  \
# 2402743  North America      US  Ohio  Columbus      1    1  1995
# 2402744  North America      US  Ohio  Columbus      1    2  1995
# 2402745  North America      US  Ohio  Columbus      1    3  1995
# 2402746  North America      US  Ohio  Columbus      1    4  1995
# 2402747  North America      US  Ohio  Columbus      1    5  1995
# ...                ...     ...   ...       ...    ...  ...   ...
# 2412003  North America      US  Ohio  Columbus      5    9  2020
# 2412004  North America      US  Ohio  Columbus      5   10  2020
# 2412005  North America      US  Ohio  Columbus      5   11  2020
# 2412006  North America      US  Ohio  Columbus      5   12  2020
# 2412007  North America      US  Ohio  Columbus      5   13  2020
#
#          AvgTemperature
# 2402743            42.4
# 2402744            21.4
# 2402745            22.5
# 2402746            14.3
# 2402747             8.1
# ...                 ...
# 2412003            38.7
# 2412004            47.0
# 2412005            42.3
# 2412006            45.4
# 2412007            46.7
#
# [9265 rows x 8 columns]

# %%
dfsavannah = df[(df['State']=='Georgia') & (df['City']=='Savannah')]
dfsavannah
# Out:
#                 Region Country    State      City  Month  Day  Year  \
# 1794721  North America      US  Georgia  Savannah      1    1  1995
# 1794722  North America      US  Georgia  Savannah      1    2  1995
# 1794723  North America      US  Georgia  Savannah      1    3  1995
# 1794724  North America      US  Georgia  Savannah      1    4  1995
# 1794725  North America      US  Georgia  Savannah      1    5  1995
# ...                ...     ...      ...       ...    ...  ...   ...
# 1803981  North America      US  Georgia  Savannah      5    9  2020
# 1803982  North America      US  Georgia  Savannah      5   10  2020
# 1803983  North America      US  Georgia  Savannah      5   11  2020
# 1803984  North America      US  Georgia  Savannah      5   12  2020
# 1803985  North America      US  Georgia  Savannah      5   13  2020
#
#          AvgTemperature
# 1794721            51.2
# 1794722            54.4
# 1794723            44.5
# 1794724            40.5
# 1794725            37.7
# ...                 ...
# 1803981            67.6
# 1803982            63.6
# 1803983            68.4
# 1803984            63.5
# 1803985            59.1
#
# [9265 rows x 8 columns]

# %%
dfcolumbus['Month and year'] = dfcolumbus['Month'].astype(str) + '-' + dfcolumbus['Year'].astype(str)
dfcolumbus
# Out:
# C:\Users\jason\AppData\Local\Temp/ipykernel_23540/2203943361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfcolumbus['Month and year'] = dfcolumbus['Month'].astype(str) + '-' + dfcolumbus['Year'].astype(str)
#                 Region Country State      City  Month  Day  Year  \
# 2402743  North America      US  Ohio  Columbus      1    1  1995
# 2402744  North America      US  Ohio  Columbus      1    2  1995
# 2402745  North America      US  Ohio  Columbus      1    3  1995
# 2402746  North America      US  Ohio  Columbus      1    4  1995
# 2402747  North America      US  Ohio  Columbus      1    5  1995
# ...                ...     ...   ...       ...    ...  ...   ...
# 2412003  North America      US  Ohio  Columbus      5    9  2020
# 2412004  North America      US  Ohio  Columbus      5   10  2020
# 2412005  North America      US  Ohio  Columbus      5   11  2020
# 2412006  North America      US  Ohio  Columbus      5   12  2020
# 2412007  North America      US  Ohio  Columbus      5   13  2020
#
#          AvgTemperature Month and year
# 2402743            42.4         1-1995
# 2402744            21.4         1-1995
# 2402745            22.5         1-1995
# 2402746            14.3         1-1995
# 2402747             8.1         1-1995
# ...                 ...            ...
# 2412003            38.7         5-2020
# 2412004            47.0         5-2020
# 2412005            42.3         5-2020
# 2412006            45.4         5-2020
# 2412007            46.7         5-2020
#
# [9265 rows x 9 columns]

# %%
#dfcolumbus.groupby('Month and year').mean().sort_values(by=['Month and year'], ascending=True).head(45)
dfcolumbusinjan = dfcolumbus[dfcolumbus['Month']==1]
dfcolumbusinjan
# Out:
#                 Region Country State      City  Month  Day  Year  \
# 2402743  North America      US  Ohio  Columbus      1    1  1995
# 2402744  North America      US  Ohio  Columbus      1    2  1995
# 2402745  North America      US  Ohio  Columbus      1    3  1995
# 2402746  North America      US  Ohio  Columbus      1    4  1995
# 2402747  North America      US  Ohio  Columbus      1    5  1995
# ...                ...     ...   ...       ...    ...  ...   ...
# 2411900  North America      US  Ohio  Columbus      1   27  2020
# 2411901  North America      US  Ohio  Columbus      1   28  2020
# 2411902  North America      US  Ohio  Columbus      1   29  2020
# 2411903  North America      US  Ohio  Columbus      1   30  2020
# 2411904  North America      US  Ohio  Columbus      1   31  2020
#
#          AvgTemperature Month and year
# 2402743            42.4         1-1995
# 2402744            21.4         1-1995
# 2402745            22.5         1-1995
# 2402746            14.3         1-1995
# 2402747             8.1         1-1995
# ...                 ...            ...
# 2411900            34.8         1-2020
# 2411901            33.1         1-2020
# 2411902            32.6         1-2020
# 2411903            32.0         1-2020
# 2411904            32.5         1-2020
#
# [806 rows x 9 columns]

# %%
dfcolumbusinjan.groupby('Month and year', as_index = False).mean()
# Out:
#    Month and year  Month   Day    Year  AvgTemperature
# 0          1-1995    1.0  16.0  1995.0       29.887097
# 1          1-1996    1.0  16.0  1996.0       27.932258
# 2          1-1997    1.0  16.0  1997.0       27.803226
# 3          1-1998    1.0  16.0  1998.0       37.387097
# 4          1-1999    1.0  16.0  1999.0       27.216129
# 5          1-2000    1.0  16.0  2000.0       27.609677
# 6          1-2001    1.0  16.0  2001.0       28.974194
# 7          1-2002    1.0  16.0  2002.0       35.461290
# 8          1-2003    1.0  16.0  2003.0       23.432258
# 9          1-2004    1.0  16.0  2004.0       24.690323
# 10         1-2005    1.0  16.0  2005.0       31.212903
# 11         1-2006    1.0  16.0  2006.0       40.303226
# 12         1-2007    1.0  16.0  2007.0       34.964516
# 13         1-2008    1.0  16.0  2008.0       31.561290
# 14         1-2009    1.0  16.0  2009.0       22.951613
# 15         1-2010    1.0  16.0  2010.0       26.193548
# 16         1-2011    1.0  16.0  2011.0       25.322581
# 17         1-2012    1.0  16.0  2012.0       33.822581
# 18         1-2013    1.0  16.0  2013.0       33.390323
# 19         1-2014    1.0  16.0  2014.0       22.996774
# 20         1-2015    1.0  16.0  2015.0       25.970968
# 21         1-2016    1.0  16.0  2016.0       28.280645
# 22         1-2017    1.0  16.0  2017.0       36.877419
# 23         1-2018    1.0  16.0  2018.0       27.032258
# 24         1-2019    1.0  16.0  2019.0       29.112903
# 25         1-2020    1.0  16.0  2020.0       35.896774

# %%
dfsavannah
# Out:
#                 Region Country    State      City  Month  Day  Year  \
# 1794721  North America      US  Georgia  Savannah      1    1  1995
# 1794722  North America      US  Georgia  Savannah      1    2  1995
# 1794723  North America      US  Georgia  Savannah      1    3  1995
# 1794724  North America      US  Georgia  Savannah      1    4  1995
# 1794725  North America      US  Georgia  Savannah      1    5  1995
# ...                ...     ...      ...       ...    ...  ...   ...
# 1803981  North America      US  Georgia  Savannah      5    9  2020
# 1803982  North America      US  Georgia  Savannah      5   10  2020
# 1803983  North America      US  Georgia  Savannah      5   11  2020
# 1803984  North America      US  Georgia  Savannah      5   12  2020
# 1803985  North America      US  Georgia  Savannah      5   13  2020
#
#          AvgTemperature
# 1794721            51.2
# 1794722            54.4
# 1794723            44.5
# 1794724            40.5
# 1794725            37.7
# ...                 ...
# 1803981            67.6
# 1803982            63.6
# 1803983            68.4
# 1803984            63.5
# 1803985            59.1
#
# [9265 rows x 8 columns]

# %%
dfsavannah['Month and year'] = dfsavannah['Month'].astype(str) + '-' + dfsavannah['Year'].astype(str)
dfsavannah
# Out:
# C:\Users\jason\AppData\Local\Temp/ipykernel_23540/700559480.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsavannah['Month and year'] = dfsavannah['Month'].astype(str) + '-' + dfsavannah['Year'].astype(str)
#                 Region Country    State      City  Month  Day  Year  \
# 1794721  North America      US  Georgia  Savannah      1    1  1995
# 1794722  North America      US  Georgia  Savannah      1    2  1995
# 1794723  North America      US  Georgia  Savannah      1    3  1995
# 1794724  North America      US  Georgia  Savannah      1    4  1995
# 1794725  North America      US  Georgia  Savannah      1    5  1995
# ...                ...     ...      ...       ...    ...  ...   ...
# 1803981  North America      US  Georgia  Savannah      5    9  2020
# 1803982  North America      US  Georgia  Savannah      5   10  2020
# 1803983  North America      US  Georgia  Savannah      5   11  2020
# 1803984  North America      US  Georgia  Savannah      5   12  2020
# 1803985  North America      US  Georgia  Savannah      5   13  2020
#
#          AvgTemperature Month and year
# 1794721            51.2         1-1995
# 1794722            54.4         1-1995
# 1794723            44.5         1-1995
# 1794724            40.5         1-1995
# 1794725            37.7         1-1995
# ...                 ...            ...
# 1803981            67.6         5-2020
# 1803982            63.6         5-2020
# 1803983            68.4         5-2020
# 1803984            63.5         5-2020
# 1803985            59.1         5-2020
#
# [9265 rows x 9 columns]

# %%
dfsavannahinjan = dfsavannah[dfsavannah['Month']== 1]
dfsavannahinjan
# Out:
#                 Region Country    State      City  Month  Day  Year  \
# 1794721  North America      US  Georgia  Savannah      1    1  1995
# 1794722  North America      US  Georgia  Savannah      1    2  1995
# 1794723  North America      US  Georgia  Savannah      1    3  1995
# 1794724  North America      US  Georgia  Savannah      1    4  1995
# 1794725  North America      US  Georgia  Savannah      1    5  1995
# ...                ...     ...      ...       ...    ...  ...   ...
# 1803878  North America      US  Georgia  Savannah      1   27  2020
# 1803879  North America      US  Georgia  Savannah      1   28  2020
# 1803880  North America      US  Georgia  Savannah      1   29  2020
# 1803881  North America      US  Georgia  Savannah      1   30  2020
# 1803882  North America      US  Georgia  Savannah      1   31  2020
#
#          AvgTemperature Month and year
# 1794721            51.2         1-1995
# 1794722            54.4         1-1995
# 1794723            44.5         1-1995
# 1794724            40.5         1-1995
# 1794725            37.7         1-1995
# ...                 ...            ...
# 1803878            53.8         1-2020
# 1803879            50.0         1-2020
# 1803880            48.3         1-2020
# 1803881            52.4         1-2020
# 1803882            49.5         1-2020
#
# [806 rows x 9 columns]

# %%
dfsavannahinjan.groupby('Month and year', as_index = False).mean()
# Out:
#    Month and year  Month   Day    Year  AvgTemperature
# 0          1-1995    1.0  16.0  1995.0       50.222581
# 1          1-1996    1.0  16.0  1996.0       49.445161
# 2          1-1997    1.0  16.0  1997.0       50.403226
# 3          1-1998    1.0  16.0  1998.0       52.270968
# 4          1-1999    1.0  16.0  1999.0       47.158065
# 5          1-2000    1.0  16.0  2000.0       48.229032
# 6          1-2001    1.0  16.0  2001.0       45.696774
# 7          1-2002    1.0  16.0  2002.0       51.283871
# 8          1-2003    1.0  16.0  2003.0       45.241935
# 9          1-2004    1.0  16.0  2004.0       47.680645
# 10         1-2005    1.0  16.0  2005.0       51.138710
# 11         1-2006    1.0  16.0  2006.0       53.793548
# 12         1-2007    1.0  16.0  2007.0       52.603226
# 13         1-2008    1.0  16.0  2008.0       44.090323
# 14         1-2009    1.0  16.0  2009.0       50.422581
# 15         1-2010    1.0  16.0  2010.0       44.909677
# 16         1-2011    1.0  16.0  2011.0       44.883871
# 17         1-2012    1.0  16.0  2012.0       53.196774
# 18         1-2013    1.0  16.0  2013.0       55.867742
# 19         1-2014    1.0  16.0  2014.0       46.048387
# 20         1-2015    1.0  16.0  2015.0       49.251613
# 21         1-2016    1.0  16.0  2016.0       48.158065
# 22         1-2017    1.0  16.0  2017.0       56.612903
# 23         1-2018    1.0  16.0  2018.0       46.116129
# 24         1-2019    1.0  16.0  2019.0       52.035484
# 25         1-2020    1.0  16.0  2020.0       56.300000

# %%
# plt.figure().add_axes([0,0,2.5,2.5]).plot(dfsavannahinjan.groupby('Month and year', as_index = False).mean()['Month and year'], dfsavannahinjan.groupby('Month and year', as_index = False).mean()['AvgTemperature'], 'b')
# plt.figure().add_axes([0,0,2.5,2.5]).plot(dfcolumbusinjan.groupby('Month and year', as_index = False).mean()['Month and year'], dfcolumbusinjan.groupby('Month and year', as_index = False).mean()['AvgTemperature'], 'r')

# %%
plt.figure(figsize=(10,7),dpi=100)
plt.grid()
plt.xticks(rotation = 'vertical')
plt.plot(dfcolumbusinjan.groupby('Month and year', as_index = False).mean()['Month and year'], dfcolumbusinjan.groupby('Month and year', as_index = False).mean()['AvgTemperature'], label = 'Columbus', marker = '.')
plt.plot(dfsavannahinjan.groupby('Month and year', as_index = False).mean()['Month and year'], dfsavannahinjan.groupby('Month and year', as_index = False).mean()['AvgTemperature'], label = 'savannah', marker = '.')
plt.legend()

# %%
dfbeijing = df[df['City']=='Beijing']
dfbeijing
# Out:
#        Region Country State     City  Month  Day  Year  AvgTemperature
# 256928   Asia   China   NaN  Beijing      1    1  1995            28.0
# 256929   Asia   China   NaN  Beijing      1    2  1995            29.0
# 256930   Asia   China   NaN  Beijing      1    3  1995            29.9
# 256931   Asia   China   NaN  Beijing      1    4  1995            34.5
# 256932   Asia   China   NaN  Beijing      1    5  1995            36.6
# ...       ...     ...   ...      ...    ...  ...   ...             ...
# 266189   Asia   China   NaN  Beijing      5    9  2020            60.6
# 266190   Asia   China   NaN  Beijing      5   10  2020            69.4
# 266191   Asia   China   NaN  Beijing      5   11  2020            73.0
# 266192   Asia   China   NaN  Beijing      5   12  2020            66.5
# 266193   Asia   China   NaN  Beijing      5   13  2020            72.5
#
# [9266 rows x 8 columns]

# %%
dfbeijing['Month and year'] = dfbeijing['Month'].astype(str) + '-' + dfbeijing['Year'].astype(str)
dfbeijing
# Out:
# C:\Users\jason\AppData\Local\Temp/ipykernel_23540/812932979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfbeijing['Month and year'] = dfbeijing['Month'].astype(str) + '-' + dfbeijing['Year'].astype(str)
#        Region Country State     City  Month  Day  Year  AvgTemperature  \
# 256928   Asia   China   NaN  Beijing      1    1  1995            28.0
# 256929   Asia   China   NaN  Beijing      1    2  1995            29.0
# 256930   Asia   China   NaN  Beijing      1    3  1995            29.9
# 256931   Asia   China   NaN  Beijing      1    4  1995            34.5
# 256932   Asia   China   NaN  Beijing      1    5  1995            36.6
# ...       ...     ...   ...      ...    ...  ...   ...             ...
# 266189   Asia   China   NaN  Beijing      5    9  2020            60.6
# 266190   Asia   China   NaN  Beijing      5   10  2020            69.4
# 266191   Asia   China   NaN  Beijing      5   11  2020            73.0
# 266192   Asia   China   NaN  Beijing      5   12  2020            66.5
# 266193   Asia   China   NaN  Beijing      5   13  2020            72.5
#
#        Month and year
# 256928         1-1995
# 256929         1-1995
# 256930         1-1995
# 256931         1-1995
# 256932         1-1995
# ...               ...
# 266189         5-2020
# 266190         5-2020
# 266191         5-2020
# 266192         5-2020
# 266193         5-2020
#
# [9266 rows x 9 columns]

# %%
dfbeijing[dfbeijing['Month']== 1].groupby('Month and year', as_index=False).mean()
# Out:
#    Month and year  Month   Day    Year  AvgTemperature
# 0          1-1995    1.0  16.0  1995.0       30.100000
# 1          1-1996    1.0  16.0  1996.0       27.838710
# 2          1-1997    1.0  16.0  1997.0       23.574194
# 3          1-1998    1.0  16.0  1998.0       25.032258
# 4          1-1999    1.0  16.0  1999.0       24.732258
# 5          1-2000    1.0  16.0  2000.0       19.574194
# 6          1-2001    1.0  16.0  2001.0       21.480645
# 7          1-2002    1.0  16.0  2002.0       32.600000
# 8          1-2003    1.0  16.0  2003.0       26.480645
# 9          1-2004    1.0  16.0  2004.0       27.345161
# 10         1-2005    1.0  16.0  2005.0       26.551613
# 11         1-2006    1.0  16.0  2006.0       28.058065
# 12         1-2007    1.0  16.0  2007.0       28.567742
# 13         1-2008    1.0  16.0  2008.0       25.274194
# 14         1-2009    1.0  16.0  2009.0       25.703226
# 15         1-2010    1.0  16.0  2010.0       21.174194
# 16         1-2011    1.0  16.0  2011.0       22.316129
# 17         1-2012    1.0  16.0  2012.0       23.358065
# 18         1-2013    1.0  16.0  2013.0       22.616129
# 19         1-2014    1.0  16.0  2014.0       30.387097
# 20         1-2015    1.0  16.0  2015.0       29.661290
# 21         1-2016    1.0  16.0  2016.0       23.080645
# 22         1-2017    1.0  16.0  2017.0       28.132258
# 23         1-2018    1.0  16.0  2018.0       21.280645
# 24         1-2019    1.0  16.0  2019.0       24.141935
# 25         1-2020    1.0  16.0  2020.0       28.948387

# %%
plt.figure(figsize=(10,7),dpi=100)
plt.grid()
plt.xticks(rotation = 'vertical')
plt.plot(dfcolumbusinjan.groupby('Month and year', as_index = False).mean()['Month and year'], dfcolumbusinjan.groupby('Month and year', as_index = False).mean()['AvgTemperature'], label = 'Columbus', marker = '.')
plt.plot(dfbeijing[dfbeijing['Month']== 1].groupby('Month and year', as_index=False).mean()['Month and year'], dfbeijing[dfbeijing['Month']== 1].groupby('Month and year', as_index=False).mean()['AvgTemperature'], label = 'Beijing', marker = '.')
plt.legend()

# %%
dfshanghai = df[df['City']=='Shanghai']
dfshanghai
# Out:
#        Region Country State      City  Month  Day  Year  AvgTemperature
# 284726   Asia   China   NaN  Shanghai      1    1  1995            40.1
# 284727   Asia   China   NaN  Shanghai      1    2  1995            42.3
# 284728   Asia   China   NaN  Shanghai      1    3  1995            36.5
# 284729   Asia   China   NaN  Shanghai      1    4  1995            36.3
# 284730   Asia   China   NaN  Shanghai      1    5  1995            38.5
# ...       ...     ...   ...       ...    ...  ...   ...             ...
# 293987   Asia   China   NaN  Shanghai      5    9  2020            69.3
# 293988   Asia   China   NaN  Shanghai      5   10  2020            68.5
# 293989   Asia   China   NaN  Shanghai      5   11  2020            73.0
# 293990   Asia   China   NaN  Shanghai      5   12  2020            76.1
# 293991   Asia   China   NaN  Shanghai      5   13  2020            77.0
#
# [9266 rows x 8 columns]

# %%
dfshanghai['Month and year'] = dfshanghai['Month'].astype(str) + '-' + dfshanghai['Year'].astype(str)
dfshanghai
# Out:
# C:\Users\jason\AppData\Local\Temp/ipykernel_23540/3776250498.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfshanghai['Month and year'] = dfshanghai['Month'].astype(str) + '-' + dfshanghai['Year'].astype(str)
#        Region Country State      City  Month  Day  Year  AvgTemperature  \
# 284726   Asia   China   NaN  Shanghai      1    1  1995            40.1
# 284727   Asia   China   NaN  Shanghai      1    2  1995            42.3
# 284728   Asia   China   NaN  Shanghai      1    3  1995            36.5
# 284729   Asia   China   NaN  Shanghai      1    4  1995            36.3
# 284730   Asia   China   NaN  Shanghai      1    5  1995            38.5
# ...       ...     ...   ...       ...    ...  ...   ...             ...
# 293987   Asia   China   NaN  Shanghai      5    9  2020            69.3
# 293988   Asia   China   NaN  Shanghai      5   10  2020            68.5
# 293989   Asia   China   NaN  Shanghai      5   11  2020            73.0
# 293990   Asia   China   NaN  Shanghai      5   12  2020            76.1
# 293991   Asia   China   NaN  Shanghai      5   13  2020            77.0
#
#        Month and year
# 284726         1-1995
# 284727         1-1995
# 284728         1-1995
# 284729         1-1995
# 284730         1-1995
# ...               ...
# 293987         5-2020
# 293988         5-2020
# 293989         5-2020
# 293990         5-2020
# 293991         5-2020
#
# [9266 rows x 9 columns]

# %%
dfshanghai[dfshanghai['Month']==1].groupby('Month and year', as_index = False).mean()
# Out:
#    Month and year  Month   Day    Year  AvgTemperature
# 0          1-1995    1.0  16.0  1995.0       40.358065
# 1          1-1996    1.0  16.0  1996.0       39.154839
# 2          1-1997    1.0  16.0  1997.0       39.061290
# 3          1-1998    1.0  16.0  1998.0       40.287097
# 4          1-1999    1.0  16.0  1999.0       39.025806
# 5          1-2000    1.0  16.0  2000.0       41.035484
# 6          1-2001    1.0  16.0  2001.0       42.900000
# 7          1-2002    1.0  16.0  2002.0       44.067742
# 8          1-2003    1.0  16.0  2003.0       38.954839
# 9          1-2004    1.0  16.0  2004.0       40.467742
# 10         1-2005    1.0  16.0  2005.0       37.880645
# 11         1-2006    1.0  16.0  2006.0       43.238710
# 12         1-2007    1.0  16.0  2007.0       41.625806
# 13         1-2008    1.0  16.0  2008.0       34.929032
# 14         1-2009    1.0  16.0  2009.0       39.270968
# 15         1-2010    1.0  16.0  2010.0       42.070968
# 16         1-2011    1.0  16.0  2011.0       34.758065
# 17         1-2012    1.0  16.0  2012.0       40.580645
# 18         1-2013    1.0  16.0  2013.0       41.122581
# 19         1-2014    1.0  16.0  2014.0       45.454839
# 20         1-2015    1.0  16.0  2015.0       44.187097
# 21         1-2016    1.0  16.0  2016.0       41.225806
# 22         1-2017    1.0  16.0  2017.0       45.270968
# 23         1-2018    1.0  16.0  2018.0       36.151613
# 24         1-2019    1.0  16.0  2019.0       38.958065
# 25         1-2020    1.0  16.0  2020.0       46.038710

# %%
plt.figure(figsize=(10,7),dpi=(100))
plt.grid()
plt.xticks(rotation = 'vertical')
plt.plot(dfshanghai[dfshanghai['Month']==1].groupby('Month and year', as_index = False).mean()['Month and year'], dfshanghai[dfshanghai['Month']==1].groupby('Month and year', as_index = False).mean()['AvgTemperature'], label = 'Shanghai', marker='.')
plt.plot(dfsavannah[dfsavannah['Month']==1].groupby('Month and year', as_index = False).mean()['Month and year'], dfsavannah[dfsavannah['Month']==1].groupby('Month and year', as_index = False).mean()['AvgTemperature'], label = 'Savannah', marker='.')
plt.legend()

# %%
#Can you conclude whether the arctic air patterns vs the siberian air patterns are completely different or not?

# %%
chinadiff = dfbeijing[dfbeijing['Month']==1].groupby('Month and year').mean()['AvgTemperature'] - dfshanghai[dfshanghai['Month']==1].groupby('Month and year').mean()['AvgTemperature']
chinadiff
# Out:
# Month and year
# 1-1995   -10.258065
# 1-1996   -11.316129
# 1-1997   -15.487097
# 1-1998   -15.254839
# 1-1999   -14.293548
# 1-2000   -21.461290
# 1-2001   -21.419355
# 1-2002   -11.467742
# 1-2003   -12.474194
# 1-2004   -13.122581
# 1-2005   -11.329032
# 1-2006   -15.180645
# 1-2007   -13.058065
# 1-2008    -9.654839
# 1-2009   -13.567742
# 1-2010   -20.896774
# 1-2011   -12.441935
# 1-2012   -17.222581
# 1-2013   -18.506452
# 1-2014   -15.067742
# 1-2015   -14.525806
# 1-2016   -18.145161
# 1-2017   -17.138710
# 1-2018   -14.870968
# 1-2019   -14.816129
# 1-2020   -17.090323
# Name: AvgTemperature, dtype: float64

# %%
usdiff = dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'] - dfsavannah[dfsavannah['Month']==1].groupby('Month and year').mean()['AvgTemperature']
-usdiff
usdiff.index
# Out:
# Index(['1-1995', '1-1996', '1-1997', '1-1998', '1-1999', '1-2000', '1-2001',
#        '1-2002', '1-2003', '1-2004', '1-2005', '1-2006', '1-2007', '1-2008',
#        '1-2009', '1-2010', '1-2011', '1-2012', '1-2013', '1-2014', '1-2015',
#        '1-2016', '1-2017', '1-2018', '1-2019', '1-2020'],
#       dtype='object', name='Month and year')

# %%
dfcolumbusjanavg = dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year', as_index = False).mean()
#dfcolumbus['diffwithsavannah'] = dfsavannah[dfsavannah['Month']==1].groupby('Month and year').mean()['AvgTemperature'] - dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature']
#dfcolumbus
dfcolumbusjanavg
dfcolumbusjanavg['diffwithsavannah'] = -usdiff
dfcolumbusjanavg
# Out:
#    Month and year  Month   Day    Year  AvgTemperature  diffwithsavannah
# 0          1-1995    1.0  16.0  1995.0       29.887097               NaN
# 1          1-1996    1.0  16.0  1996.0       27.932258               NaN
# 2          1-1997    1.0  16.0  1997.0       27.803226               NaN
# 3          1-1998    1.0  16.0  1998.0       37.387097               NaN
# 4          1-1999    1.0  16.0  1999.0       27.216129               NaN
# 5          1-2000    1.0  16.0  2000.0       27.609677               NaN
# 6          1-2001    1.0  16.0  2001.0       28.974194               NaN
# 7          1-2002    1.0  16.0  2002.0       35.461290               NaN
# 8          1-2003    1.0  16.0  2003.0       23.432258               NaN
# 9          1-2004    1.0  16.0  2004.0       24.690323               NaN
# 10         1-2005    1.0  16.0  2005.0       31.212903               NaN
# 11         1-2006    1.0  16.0  2006.0       40.303226               NaN
# 12         1-2007    1.0  16.0  2007.0       34.964516               NaN
# 13         1-2008    1.0  16.0  2008.0       31.561290               NaN
# 14         1-2009    1.0  16.0  2009.0       22.951613               NaN
# 15         1-2010    1.0  16.0  2010.0       26.193548               NaN
# 16         1-2011    1.0  16.0  2011.0       25.322581               NaN
# 17         1-2012    1.0  16.0  2012.0       33.822581               NaN
# 18         1-2013    1.0  16.0  2013.0       33.390323               NaN
# 19         1-2014    1.0  16.0  2014.0       22.996774               NaN
# 20         1-2015    1.0  16.0  2015.0       25.970968               NaN
# 21         1-2016    1.0  16.0  2016.0       28.280645               NaN
# 22         1-2017    1.0  16.0  2017.0       36.877419               NaN
# 23         1-2018    1.0  16.0  2018.0       27.032258               NaN
# 24         1-2019    1.0  16.0  2019.0       29.112903               NaN
# 25         1-2020    1.0  16.0  2020.0       35.896774               NaN

# %%
differencedata = {'Month and year': chinadiff.index,
                  'usdiff': -usdiff,
               'chinadiff': -chinadiff}
differencedf = pd.DataFrame(differencedata)
differencedf
# Out:
#                Month and year     usdiff  chinadiff
# Month and year
# 1-1995                 1-1995  20.335484  10.258065
# 1-1996                 1-1996  21.512903  11.316129
# 1-1997                 1-1997  22.600000  15.487097
# 1-1998                 1-1998  14.883871  15.254839
# 1-1999                 1-1999  19.941935  14.293548
# 1-2000                 1-2000  20.619355  21.461290
# 1-2001                 1-2001  16.722581  21.419355
# 1-2002                 1-2002  15.822581  11.467742
# 1-2003                 1-2003  21.809677  12.474194
# 1-2004                 1-2004  22.990323  13.122581
# 1-2005                 1-2005  19.925806  11.329032
# 1-2006                 1-2006  13.490323  15.180645
# 1-2007                 1-2007  17.638710  13.058065
# 1-2008                 1-2008  12.529032   9.654839
# 1-2009                 1-2009  27.470968  13.567742
# 1-2010                 1-2010  18.716129  20.896774
# 1-2011                 1-2011  19.561290  12.441935
# 1-2012                 1-2012  19.374194  17.222581
# 1-2013                 1-2013  22.477419  18.506452
# 1-2014                 1-2014  23.051613  15.067742
# 1-2015                 1-2015  23.280645  14.525806
# 1-2016                 1-2016  19.877419  18.145161
# 1-2017                 1-2017  19.735484  17.138710
# 1-2018                 1-2018  19.083871  14.870968
# 1-2019                 1-2019  22.922581  14.816129
# 1-2020                 1-2020  20.403226  17.090323

# %%
plt.figure(figsize=(10,7), dpi=100)
plt.grid()
plt.xticks(rotation = 'vertical')
plt.plot(differencedf['Month and year'],differencedf['usdiff'], label = 'US', marker = '.')
plt.plot(differencedf['Month and year'],differencedf['chinadiff'], label = 'China', marker = '.')
plt.legend()
plt.title('Difference in annual Temps of 2 cities same latitude')
plt.xlabel('year')
plt.ylabel('temp in F')
# Out:
# Text(0, 0.5, 'temp in F')

# %%
dfcolumbusjanavg.iloc[dfcolumbusjanavg[['AvgTemperature']].idxmin()['AvgTemperature']]
# Out:
# Month and year         1-2009
# Month                     1.0
# Day                      16.0
# Year                   2009.0
# AvgTemperature      22.951613
# diffwithsavannah          NaN
# Name: 14, dtype: object

# %%
differencedf['std of columbus'] = dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').std()['AvgTemperature']
differencedf['std of beijing'] = dfbeijing[dfbeijing['Month']==1].groupby('Month and year').std()['AvgTemperature']
differencedf
# Out:
#                Month and year     usdiff  chinadiff  std of columbus  \
# Month and year
# 1-1995                 1-1995  20.335484  10.258065        12.741396
# 1-1996                 1-1996  21.512903  11.316129        10.399403
# 1-1997                 1-1997  22.600000  15.487097        15.496505
# 1-1998                 1-1998  14.883871  15.254839         9.583936
# 1-1999                 1-1999  19.941935  14.293548        27.072029
# 1-2000                 1-2000  20.619355  21.461290        13.268066
# 1-2001                 1-2001  16.722581  21.419355         7.193190
# 1-2002                 1-2002  15.822581  11.467742         9.677247
# 1-2003                 1-2003  21.809677  12.474194         8.663155
# 1-2004                 1-2004  22.990323  13.122581        11.659713
# 1-2005                 1-2005  19.925806  11.329032        14.675393
# 1-2006                 1-2006  13.490323  15.180645         7.051548
# 1-2007                 1-2007  17.638710  13.058065        10.194755
# 1-2008                 1-2008  12.529032   9.654839        12.722282
# 1-2009                 1-2009  27.470968  13.567742        10.046454
# 1-2010                 1-2010  18.716129  20.896774         9.602983
# 1-2011                 1-2011  19.561290  12.441935         8.292274
# 1-2012                 1-2012  19.374194  17.222581         9.150363
# 1-2013                 1-2013  22.477419  18.506452        12.941699
# 1-2014                 1-2014  23.051613  15.067742        13.568800
# 1-2015                 1-2015  23.280645  14.525806        10.602679
# 1-2016                 1-2016  19.877419  18.145161        10.645732
# 1-2017                 1-2017  19.735484  17.138710        13.287782
# 1-2018                 1-2018  19.083871  14.870968        15.501901
# 1-2019                 1-2019  22.922581  14.816129        12.294057
# 1-2020                 1-2020  20.403226  17.090323         8.547143
#
#                 std of beijing
# Month and year
# 1-1995                3.588500
# 1-1996                3.344316
# 1-1997                6.163277
# 1-1998                5.327750
# 1-1999               23.485547
# 1-2000                4.883234
# 1-2001                6.304095
# 1-2002                4.008325
# 1-2003                6.646724
# 1-2004                5.418723
# 1-2005                3.026645
# 1-2006                3.375675
# 1-2007                3.017879
# 1-2008                4.475114
# 1-2009                4.311959
# 1-2010                8.730138
# 1-2011                3.049491
# 1-2012                3.451355
# 1-2013                4.402431
# 1-2014                4.318467
# 1-2015                3.468398
# 1-2016                5.875793
# 1-2017                4.294212
# 1-2018               23.002470
# 1-2019               23.480812
# 1-2020                3.666140

# %%
plt.figure(figsize=(10,7), dpi=100)
plt.grid()
plt.xticks(rotation = 'vertical')
plt.plot(differencedf['Month and year'],differencedf['std of columbus'], label = 'US', marker = '.')
plt.plot(differencedf['Month and year'],differencedf['std of beijing'], label = 'China', marker = '.')
plt.legend()
plt.title('Strength of the arctic high vs siberian high')
plt.xlabel('year')
plt.ylabel('temp in F')
# Out:
# Text(0, 0.5, 'temp in F')

# %%
dfcolumbus[dfcolumbus['Year']==2009].head(31)
# Out:
#                 Region Country State      City  Month  Day  Year  \
# 2407857  North America      US  Ohio  Columbus      1    1  2009
# 2407858  North America      US  Ohio  Columbus      1    2  2009
# 2407859  North America      US  Ohio  Columbus      1    3  2009
# 2407860  North America      US  Ohio  Columbus      1    4  2009
# 2407861  North America      US  Ohio  Columbus      1    5  2009
# 2407862  North America      US  Ohio  Columbus      1    6  2009
# 2407863  North America      US  Ohio  Columbus      1    7  2009
# 2407864  North America      US  Ohio  Columbus      1    8  2009
# 2407865  North America      US  Ohio  Columbus      1    9  2009
# 2407866  North America      US  Ohio  Columbus      1   10  2009
# 2407867  North America      US  Ohio  Columbus      1   11  2009
# 2407868  North America      US  Ohio  Columbus      1   12  2009
# 2407869  North America      US  Ohio  Columbus      1   13  2009
# 2407870  North America      US  Ohio  Columbus      1   14  2009
# 2407871  North America      US  Ohio  Columbus      1   15  2009
# 2407872  North America      US  Ohio  Columbus      1   16  2009
# 2407873  North America      US  Ohio  Columbus      1   17  2009
# 2407874  North America      US  Ohio  Columbus      1   18  2009
# 2407875  North America      US  Ohio  Columbus      1   19  2009
# 2407876  North America      US  Ohio  Columbus      1   20  2009
# 2407877  North America      US  Ohio  Columbus      1   21  2009
# 2407878  North America      US  Ohio  Columbus      1   22  2009
# 2407879  North America      US  Ohio  Columbus      1   23  2009
# 2407880  North America      US  Ohio  Columbus      1   24  2009
# 2407881  North America      US  Ohio  Columbus      1   25  2009
# 2407882  North America      US  Ohio  Columbus      1   26  2009
# 2407883  North America      US  Ohio  Columbus      1   27  2009
# 2407884  North America      US  Ohio  Columbus      1   28  2009
# 2407885  North America      US  Ohio  Columbus      1   29  2009
# 2407886  North America      US  Ohio  Columbus      1   30  2009
# 2407887  North America      US  Ohio  Columbus      1   31  2009
#
#          AvgTemperature Month and year
# 2407857            24.1         1-2009
# 2407858            36.2         1-2009
# 2407859            31.9         1-2009
# 2407860            38.3         1-2009
# 2407861            33.4         1-2009
# 2407862            30.2         1-2009
# 2407863            33.8         1-2009
# 2407864            24.6         1-2009
# 2407865            23.9         1-2009
# 2407866            30.9         1-2009
# 2407867            26.7         1-2009
# 2407868            28.2         1-2009
# 2407869            31.1         1-2009
# 2407870            15.5         1-2009
# 2407871             9.3         1-2009
# 2407872            -3.8         1-2009
# 2407873             4.4         1-2009
# 2407874            27.3         1-2009
# 2407875            16.1         1-2009
# 2407876            11.8         1-2009
# 2407877            11.3         1-2009
# 2407878            25.7         1-2009
# 2407879            37.3         1-2009
# 2407880            27.4         1-2009
# 2407881            15.0         1-2009
# 2407882            17.3         1-2009
# 2407883            20.6         1-2009
# 2407884            25.3         1-2009
# 2407885            21.5         1-2009
# 2407886            23.8         1-2009
# 2407887            12.4         1-2009

# %%
plt.figure(figsize=(6,6), dpi=100)
plt.grid()
plt.scatter(dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfbeijing[dfbeijing['Month']==1].groupby('Month and year').mean()['AvgTemperature'])
plt.xlabel('Temp of columbus')
plt.ylabel('Temp of Beijing')
plt.show()

# %%
from scipy import stats
stats.pearsonr(dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfbeijing[dfbeijing['Month']==1].groupby('Month and year').mean()['AvgTemperature'])
# Out:
# (0.24395954608467904, 0.2297409650058677)

# %%
#An R-Value of 0.24 means that there is hardly any correlation between the activity of the Arctic High and the Siberian High

# %%
#What about the correlation between Columbus and Savannah vs. Beijing and Shanghai?

# %%
plt.figure(figsize=(6,6), dpi=100)
plt.grid()
plt.scatter(dfsavannah[dfsavannah['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'])
plt.xlabel('Temp of savannah')
plt.ylabel('Temp of columbus')
plt.show()

# %%
stats.pearsonr(dfsavannah[dfsavannah['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'])
# Out:
# (0.7308086965276582, 2.2368761987402273e-05)

# %%
plt.figure(figsize=(6,6), dpi=100)
plt.grid()
plt.scatter(dfshanghai[dfshanghai['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfbeijing[dfbeijing['Month']==1].groupby('Month and year').mean()['AvgTemperature'])
plt.xlabel('Temp of shanghai')
plt.ylabel('Temp of beijing')
plt.show()

# %%
stats.pearsonr(dfshanghai[dfshanghai['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfbeijing[dfbeijing['Month']==1].groupby('Month and year').mean()['AvgTemperature'])
# Out:
# (0.4721131731668423, 0.01488452948541202)

# %%
#Lets study the correlation between the influence of the arctic high on the West coast vs. on the East coast!

# %%
sorted(df[df['Country']=='US']['City'].unique())
# Out:
# ['Abilene',
#  'Akron Canton',
#  'Albany',
#  'Albuquerque',
#  'Allentown',
#  'Amarillo',
#  'Anchorage',
#  'Asheville',
#  'Atlanta',
#  'Atlantic City',
#  'Austin',
#  'Baltimore',
#  'Baton Rouge',
#  'Billings',
#  'Birmingham',
#  'Bismarck',
#  'Boise',
#  'Boston',
#  'Bridgeport',
#  'Brownsville',
#  'Buffalo',
#  'Burlington',
#  'Caribou',
#  'Casper',
#  'Charleston',
#  'Charlotte',
#  'Chattanooga',
#  'Cheyenne',
#  'Chicago',
#  'Cincinnati',
#  'Cleveland',
#  'Colorado Springs',
#  'Columbia',
#  'Columbus',
#  'Concord',
#  'Corpus Christi',
#  'Dallas Ft Worth',
#  'Dayton',
#  'Daytona Beach',
#  'Denver',
#  'Des Moines',
#  'Detroit',
#  'Duluth',
#  'El Paso',
#  'Elkins',
#  'Erie',
#  'Eugene',
#  'Evansville',
#  'Fairbanks',
#  'Fargo',
#  'Flagstaff',
#  'Flint',
#  'Fort Smith',
#  'Fort Wayne',
#  'Fresno',
#  'Goodland',
#  'Grand Junction',
#  'Grand Rapids',
#  'Great Falls',
#  'Green Bay',
#  'Greensboro',
#  'Harrisburg',
#  'Hartford Springfield',
#  'Helena',
#  'Honolulu',
#  'Houston',
#  'Huntsville',
#  'Indianapolis',
#  'Jackson',
#  'Jacksonville',
#  'Juneau',
#  'Kansas City',
#  'Knoxville',
#  'Lake Charles',
#  'Lansing',
#  'Las Vegas',
#  'Lexington',
#  'Lincoln',
#  'Little Rock',
#  'Los Angeles',
#  'Louisville',
#  'Lubbock',
#  'Macon',
#  'Madison',
#  'Medford',
#  'Memphis',
#  'Miami Beach',
#  'Midland Odessa',
#  'Milwaukee',
#  'Minneapolis St. Paul',
#  'Mobile',
#  'Montgomery',
#  'Nashville',
#  'New Orleans',
#  'New York City',
#  'Newark',
#  'Norfolk',
#  'North Platte',
#  'Oklahoma City',
#  'Omaha',
#  'Orlando',
#  'Paducah',
#  'Peoria',
#  'Philadelphia',
#  'Phoenix',
#  'Pittsburgh',
#  'Pocatello',
#  'Portland',
#  'Pueblo',
#  'Raleigh Durham',
#  'Rapid City',
#  'Reno',
#  'Rhode Island',
#  'Richmond',
#  'Roanoke',
#  'Rochester',
#  'Rockford',
#  'Sacramento',
#  'Salem',
#  'Salt Lake City',
#  'San Angelo',
#  'San Antonio',
#  'San Diego',
#  'San Francisco',
#  'San Juan Puerto Rico',
#  'Sault Ste Marie',
#  'Savannah',
#  'Seattle',
#  'Shreveport',
#  'Sioux City',
#  'Sioux Falls',
#  'South Bend',
#  'Spokane',
#  'Springfield',
#  'St Louis',
#  'Syracuse',
#  'Tallahassee',
#  'Tampa St. Petersburg',
#  'Toledo',
#  'Topeka',
#  'Tucson',
#  'Tulsa',
#  'Tupelo',
#  'Waco',
#  'Washington',
#  'Washington DC',
#  'West Palm Beach',
#  'Wichita',
#  'Wichita Falls',
#  'Wilkes Barre',
#  'Wilmington',
#  'Yakima',
#  'Youngstown',
#  'Yuma']

# %%
dfsacramento = df[df['City']=='Sacramento']
dfsacramento
# Out:
#                 Region Country       State        City  Month  Day  Year  \
# 1579389  North America      US  California  Sacramento      1    1  1995
# 1579390  North America      US  California  Sacramento      1    2  1995
# 1579391  North America      US  California  Sacramento      1    3  1995
# 1579392  North America      US  California  Sacramento      1    4  1995
# 1579393  North America      US  California  Sacramento      1    5  1995
# ...                ...     ...         ...         ...    ...  ...   ...
# 1588649  North America      US  California  Sacramento      5    9  2020
# 1588650  North America      US  California  Sacramento      5   10  2020
# 1588651  North America      US  California  Sacramento      5   11  2020
# 1588652  North America      US  California  Sacramento      5   12  2020
# 1588653  North America      US  California  Sacramento      5   13  2020
#
#          AvgTemperature
# 1579389            43.0
# 1579390            40.6
# 1579391            47.5
# 1579392            49.2
# 1579393            48.6
# ...                 ...
# 1588649            74.6
# 1588650            65.4
# 1588651            62.6
# 1588652            61.1
# 1588653            60.3
#
# [9265 rows x 8 columns]

# %%
dfsacramento['Month and year'] = dfsacramento['Month'].astype(str) + '-' + dfsacramento['Year'].astype(str)
dfsacramento
# Out:
# C:\Users\jason\AppData\Local\Temp/ipykernel_23540/2419541028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfsacramento['Month and year'] = dfsacramento['Month'].astype(str) + '-' + dfsacramento['Year'].astype(str)
#                 Region Country       State        City  Month  Day  Year  \
# 1579389  North America      US  California  Sacramento      1    1  1995
# 1579390  North America      US  California  Sacramento      1    2  1995
# 1579391  North America      US  California  Sacramento      1    3  1995
# 1579392  North America      US  California  Sacramento      1    4  1995
# 1579393  North America      US  California  Sacramento      1    5  1995
# ...                ...     ...         ...         ...    ...  ...   ...
# 1588649  North America      US  California  Sacramento      5    9  2020
# 1588650  North America      US  California  Sacramento      5   10  2020
# 1588651  North America      US  California  Sacramento      5   11  2020
# 1588652  North America      US  California  Sacramento      5   12  2020
# 1588653  North America      US  California  Sacramento      5   13  2020
#
#          AvgTemperature Month and year
# 1579389            43.0         1-1995
# 1579390            40.6         1-1995
# 1579391            47.5         1-1995
# 1579392            49.2         1-1995
# 1579393            48.6         1-1995
# ...                 ...            ...
# 1588649            74.6         5-2020
# 1588650            65.4         5-2020
# 1588651            62.6         5-2020
# 1588652            61.1         5-2020
# 1588653            60.3         5-2020
#
# [9265 rows x 9 columns]

# %%
plt.figure(figsize=(6,6), dpi=100)
plt.grid()
plt.scatter(dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfsacramento[dfsacramento['Month']==1].groupby('Month and year').mean()['AvgTemperature'])
plt.xlabel('Temp of columbus')
plt.ylabel('Temp of Sacramento')
plt.show()

# %%
stats.pearsonr(dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dfsacramento[dfsacramento['Month']==1].groupby('Month and year').mean()['AvgTemperature'])[0]
# Out:
# -0.17080240556511972

# %%
dftest = df[df['City']=='Austin'] 
dftest['Month and year'] = dftest['Month'].astype(str) + '-' + dftest['Year'].astype(str)
stats.pearsonr(dfcolumbus[dfcolumbus['Month']==12].groupby('Month and year').mean()['AvgTemperature'], dftest[dftest['Month']==12].groupby('Month and year').mean()['AvgTemperature'])[0]**2
# Out:
# C:\Users\jason\AppData\Local\Temp/ipykernel_23540/3165631825.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dftest['Month and year'] = dftest['Month'].astype(str) + '-' + dftest['Year'].astype(str)
# 0.41881407107555596

# %%
#Lets make a heat map out of this!!! What other countries do you think you can make a heat map for?

# %%
citydata = []
citystate = []
cityname = []
for i in df[df['Country']=='US']['City'].unique():
    if df[df['City']==i].count()[0] == df[(df['City']=='Columbus') & (df['State']=='Ohio')].count()[0]:
        dftest = df[df['City']==i]
        dftest.loc[:, ('Month and year')] = dftest.loc[:, ('Month')].astype(str) + '-' + dftest.loc[:, ('Year')].astype(str)
        cityname.append(i)
        citystate.append([i, df[(df['City']==i) & (df['Country']=='US')]['State'].iloc[0]])
        citydata.append((stats.pearsonr(dfcolumbus[dfcolumbus['Month']==1].groupby('Month and year').mean()['AvgTemperature'], dftest[dftest['Month']==1].groupby('Month and year').mean()['AvgTemperature']))[0])
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
dflist = pd.DataFrame(list(zip(cityname, citystate, citydata)), columns=['City', 'State', 'R-value'])
dflist.sort_values(by=['R-value'],ascending=True).head(20)
# Out:
#                City                        State   R-value
# 14        San Diego      [San Diego, California] -0.383787
# 7           Phoenix           [Phoenix, Arizona] -0.348203
# 72        Las Vegas          [Las Vegas, Nevada] -0.324563
# 8            Tucson            [Tucson, Arizona] -0.319043
# 4         Anchorage          [Anchorage, Alaska] -0.281259
# 71             Reno               [Reno, Nevada] -0.266962
# 5         Fairbanks          [Fairbanks, Alaska] -0.262680
# 12      Los Angeles    [Los Angeles, California] -0.245474
# 15    San Francisco  [San Francisco, California] -0.229781
# 97          Medford            [Medford, Oregon] -0.200063
# 132          Yakima         [Yakima, Washington] -0.198830
# 13       Sacramento     [Sacramento, California] -0.170802
# 33        Pocatello           [Pocatello, Idaho] -0.118888
# 130         Seattle        [Seattle, Washington] -0.110002
# 11           Fresno         [Fresno, California] -0.105979
# 137          Casper            [Casper, Wyoming] -0.090164
# 125  Salt Lake City       [Salt Lake City, Utah] -0.076841
# 6            Juneau             [Juneau, Alaska] -0.076094
# 76      Albuquerque    [Albuquerque, New Mexico] -0.072545
# 32            Boise               [Boise, Idaho] -0.063328

# %%
import geopandas as gpd

# %%
map_df = gpd.read_file('USA_adm/USA_adm1.shp')

# %%
import cartopy.crs as crs
import cartopy.feature as cfeature

# %% [markdown]
# df.head()

# %%
from geopy.geocoders import Nominatim
import math

# %%
geolocator = Nominatim(user_agent = 'jason_duong96@hotmail.com')
geolocator.geocode('Birmingham, AL')[1]
# Out:
# (33.5206824, -86.8024326)

# %%
latitude = []
longitude = []
for i in dflist['State']:
    latitude.append(geolocator.geocode(i)[1][0])
    longitude.append(geolocator.geocode(i)[1][1])

# %%
dflist = dflist.assign(Latitude = latitude, Longitude = longitude)

# %%
for index, i in enumerate(dflist['Longitude']):
    if i > -50:
        dflist = dflist.drop(index, axis = 0)

# %%
dflist
# Out:
#            City                   State   R-value   Latitude   Longitude
# 0    Birmingham   [Birmingham, Alabama]  0.811971  33.520682  -86.802433
# 1    Huntsville   [Huntsville, Alabama]  0.832138  34.729847  -86.585901
# 2        Mobile       [Mobile, Alabama]  0.723790  30.694357  -88.043054
# 3    Montgomery   [Montgomery, Alabama]  0.760007  32.366966  -86.300648
# 4     Anchorage     [Anchorage, Alaska] -0.281259  61.216313 -149.894852
# ..          ...                     ...       ...        ...         ...
# 134   Green Bay  [Green Bay, Wisconsin]  0.880363  44.512638  -88.012579
# 135     Madison    [Madison, Wisconsin]  0.869573  43.074761  -89.383761
# 136   Milwaukee  [Milwaukee, Wisconsin]  0.891908  43.034993  -87.922497
# 137      Casper       [Casper, Wyoming] -0.090164  42.850119 -106.325138
# 138    Cheyenne     [Cheyenne, Wyoming] -0.042514  41.139981 -104.820246
#
# [139 rows x 5 columns]

# %%
figure = plt.figure(figsize=(20,12))
ax = figure.add_subplot(1,1,1, projection=crs.Mercator())
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.STATES)
# Zoom in on the US by setting longitude/latitude parameters
ax.set_extent(
    [-130, # minimum latitude
        -60, # min longitude
        24, # max latitude
        52 # max longitude
    ],
    crs=crs.PlateCarree()
)
plt.scatter(x=dflist['Longitude'], y=dflist['Latitude'], c = dflist['R-value'], s=250, alpha=1, cmap = 'hot', transform = crs.PlateCarree())
plt.colorbar(plt.scatter(x=dflist['Longitude'], y=dflist['Latitude'], c = dflist['R-value'], s=250, alpha=1, cmap = 'hot', transform = crs.PlateCarree()))
plt.show()

# %%
#Nice! You've created a map that shows the influence of the Arctic High on most major U.S cities relative to Columbus! Now can you create a film that shows this map when the month looked at is different?

# %%
from matplotlib.animation import FuncAnimation

# %%
f_d = ax.plot([], [], linewidth=2.5)
temp = ax.text(1, 1, '', ha='right', va='top', fontsize=24)

# %%
def animate(m):
    k = np.linspace(1,12,12)
    plt.title('Month of {k}')

# %%
dftest
# Out:
#                 Region Country    State      City  Month  Day  Year  \
# 2890275  North America      US  Wyoming  Cheyenne      1    1  1995
# 2890276  North America      US  Wyoming  Cheyenne      1    2  1995
# 2890277  North America      US  Wyoming  Cheyenne      1    3  1995
# 2890278  North America      US  Wyoming  Cheyenne      1    4  1995
# 2890279  North America      US  Wyoming  Cheyenne      1    5  1995
# ...                ...     ...      ...       ...    ...  ...   ...
# 2899535  North America      US  Wyoming  Cheyenne      5    9  2020
# 2899536  North America      US  Wyoming  Cheyenne      5   10  2020
# 2899537  North America      US  Wyoming  Cheyenne      5   11  2020
# 2899538  North America      US  Wyoming  Cheyenne      5   12  2020
# 2899539  North America      US  Wyoming  Cheyenne      5   13  2020
#
#          AvgTemperature Month and year
# 2890275             8.8         1-1995
# 2890276            19.0         1-1995
# 2890277            11.3         1-1995
# 2890278             5.0         1-1995
# 2890279            18.9         1-1995
# ...                 ...            ...
# 2899535            42.3         5-2020
# 2899536            43.1         5-2020
# 2899537            37.8         5-2020
# 2899538            41.9         5-2020
# 2899539            48.5         5-2020
#
# [9265 rows x 9 columns]

# %%
example = []
example.append([2,4])

# %%
example
# Out:
# [[2, 4]]

# %%
dflist
# Out:
#            City                   State   R-value   Latitude   Longitude
# 0    Birmingham   [Birmingham, Alabama]  0.811971  33.520682  -86.802433
# 1    Huntsville   [Huntsville, Alabama]  0.832138  34.729847  -86.585901
# 2        Mobile       [Mobile, Alabama]  0.723790  30.694357  -88.043054
# 3    Montgomery   [Montgomery, Alabama]  0.760007  32.366966  -86.300648
# 4     Anchorage     [Anchorage, Alaska] -0.281259  61.216313 -149.894852
# ..          ...                     ...       ...        ...         ...
# 134   Green Bay  [Green Bay, Wisconsin]  0.880363  44.512638  -88.012579
# 135     Madison    [Madison, Wisconsin]  0.869573  43.074761  -89.383761
# 136   Milwaukee  [Milwaukee, Wisconsin]  0.891908  43.034993  -87.922497
# 137      Casper       [Casper, Wyoming] -0.090164  42.850119 -106.325138
# 138    Cheyenne     [Cheyenne, Wyoming] -0.042514  41.139981 -104.820246
#
# [139 rows x 5 columns]

# %%
dflist= dflist[['City', 'State', 'Latitude', 'Longitude', 'R-value']]
dflist
# Out:
#            City                   State   Latitude   Longitude   R-value
# 0    Birmingham   [Birmingham, Alabama]  33.520682  -86.802433  0.811971
# 1    Huntsville   [Huntsville, Alabama]  34.729847  -86.585901  0.832138
# 2        Mobile       [Mobile, Alabama]  30.694357  -88.043054  0.723790
# 3    Montgomery   [Montgomery, Alabama]  32.366966  -86.300648  0.760007
# 4     Anchorage     [Anchorage, Alaska]  61.216313 -149.894852 -0.281259
# ..          ...                     ...        ...         ...       ...
# 134   Green Bay  [Green Bay, Wisconsin]  44.512638  -88.012579  0.880363
# 135     Madison    [Madison, Wisconsin]  43.074761  -89.383761  0.869573
# 136   Milwaukee  [Milwaukee, Wisconsin]  43.034993  -87.922497  0.891908
# 137      Casper       [Casper, Wyoming]  42.850119 -106.325138 -0.090164
# 138    Cheyenne     [Cheyenne, Wyoming]  41.139981 -104.820246 -0.042514
#
# [139 rows x 5 columns]

# %%
dfexample = dflist

# %%
dfcolumbus
# Out:
#                 Region Country State      City  Month  Day  Year  \
# 2402743  North America      US  Ohio  Columbus      1    1  1995
# 2402744  North America      US  Ohio  Columbus      1    2  1995
# 2402745  North America      US  Ohio  Columbus      1    3  1995
# 2402746  North America      US  Ohio  Columbus      1    4  1995
# 2402747  North America      US  Ohio  Columbus      1    5  1995
# ...                ...     ...   ...       ...    ...  ...   ...
# 2412003  North America      US  Ohio  Columbus      5    9  2020
# 2412004  North America      US  Ohio  Columbus      5   10  2020
# 2412005  North America      US  Ohio  Columbus      5   11  2020
# 2412006  North America      US  Ohio  Columbus      5   12  2020
# 2412007  North America      US  Ohio  Columbus      5   13  2020
#
#          AvgTemperature Month and year
# 2402743            42.4         1-1995
# 2402744            21.4         1-1995
# 2402745            22.5         1-1995
# 2402746            14.3         1-1995
# 2402747             8.1         1-1995
# ...                 ...            ...
# 2412003            38.7         5-2020
# 2412004            47.0         5-2020
# 2412005            42.3         5-2020
# 2412006            45.4         5-2020
# 2412007            46.7         5-2020
#
# [9265 rows x 9 columns]

# %%
for i in range(1,13,1):
    citydata = []
    for k in df[df['Country']=='US']['City'].unique():
        if df[df['City']==k].count()[0] == df[(df['City']=='Columbus') & (df['State']=='Ohio')].count()[0]:
            dftest = df[df['City']==k]
            dftest.loc[:, ('Month and year')] = dftest.loc[:, ('Month')].astype(str) + '-' + dftest.loc[:, ('Year')].astype(str)
            citydata.append((stats.pearsonr(dfcolumbus[dfcolumbus['Month']==i].groupby('Month and year').mean()['AvgTemperature'], dftest[dftest['Month']==i].groupby('Month and year').mean()['AvgTemperature']))[0])
    dflist.insert(3+i, 'x', citydata, True)
# Out:
# C:\Users\jason\anaconda3\lib\site-packages\pandas\core\indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
dflist
# Out:
#            City                   State   Latitude   Longitude         x  \
# 0    Birmingham   [Birmingham, Alabama]  33.520682  -86.802433  0.811971
# 1    Huntsville   [Huntsville, Alabama]  34.729847  -86.585901  0.832138
# 2        Mobile       [Mobile, Alabama]  30.694357  -88.043054  0.723790
# 3    Montgomery   [Montgomery, Alabama]  32.366966  -86.300648  0.760007
# 4     Anchorage     [Anchorage, Alaska]  61.216313 -149.894852 -0.281259
# ..          ...                     ...        ...         ...       ...
# 134   Green Bay  [Green Bay, Wisconsin]  44.512638  -88.012579  0.880363
# 135     Madison    [Madison, Wisconsin]  43.074761  -89.383761  0.869573
# 136   Milwaukee  [Milwaukee, Wisconsin]  43.034993  -87.922497  0.891908
# 137      Casper       [Casper, Wyoming]  42.850119 -106.325138 -0.090164
# 138    Cheyenne     [Cheyenne, Wyoming]  41.139981 -104.820246 -0.042514
#
#             x         x         x         x         x         x         x  \
# 0    0.764813  0.674194  0.787112  0.794296  0.905613  0.531440  0.469047
# 1    0.810201  0.842708  0.825684  0.857858  0.889830  0.512275  0.491537
# 2    0.658819  0.638844  0.618790  0.597903  0.724852  0.087602  0.239195
# 3    0.641159  0.669242  0.673749  0.366611  0.344063  0.201661  0.171770
# 4   -0.042835 -0.439030 -0.044007 -0.221717  0.806155 -0.192204 -0.058120
# ..        ...       ...       ...       ...       ...       ...       ...
# 134  0.786029  0.821850  0.767080  0.684367  0.421674  0.888074  0.837421
# 135  0.800682  0.889966  0.815300  0.845669  0.915276  0.911449  0.791772
# 136  0.852327  0.829123  0.340670  0.273455  0.585788  0.922624  0.848922
# 137  0.123568  0.495131  0.349786  0.410937  0.698821  0.376204  0.185031
# 138  0.187168  0.515446  0.385054  0.364682  0.710810  0.271514  0.302499
#
#             x         x         x         x   R-value
# 0    0.782188  0.586545  0.859729  0.904047  0.811971
# 1    0.821712  0.595810  0.887162  0.908491  0.832138
# 2    0.627794  0.295005  0.724522  0.835678  0.723790
# 3    0.793530  0.509298  0.780341  0.854806  0.760007
# 4    0.386019  0.005732 -0.434079  0.247991 -0.281259
# ..        ...       ...       ...       ...       ...
# 134  0.801715  0.757332  0.913283  0.823348  0.880363
# 135  0.820108  0.709511  0.927626  0.838342  0.869573
# 136  0.837704  0.770765  0.930109  0.878153  0.891908
# 137  0.538590  0.108696  0.359709  0.427056 -0.090164
# 138  0.673603  0.202884  0.312926  0.388143 -0.042514
#
# [139 rows x 17 columns]

# %%
from IPython import display
from matplotlib import animation
months = ['January','Feburary', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']
for i in range(1,13,1):
    figure = plt.figure(figsize=(20,12))
    ax = figure.add_subplot(1,1,1, projection=crs.Mercator())
    ax.add_feature(cfeature.COASTLINE)
    ax.add_feature(cfeature.STATES)
    # Zoom in on the US by setting longitude/latitude parameters
    ax.set_extent(
    [-130, # minimum latitude
        -60, # min longitude
        24, # max latitude
        52 # max longitude
    ],
    crs=crs.PlateCarree()
    )
    display.clear_output(wait=True)
    plt.scatter(x=dflist['Longitude'], y=dflist['Latitude'], c = dflist.iloc[:, 3+i], s=250, alpha=1, cmap = 'hot', transform = crs.PlateCarree())
    plt.title('Spread of arctic air to U.S cities relative to Columbus')
    plt.colorbar(plt.scatter(x=dflist['Longitude'], y=dflist['Latitude'], c = dflist.iloc[:, 3+i], s=250, alpha=1, cmap = 'hot', transform = crs.PlateCarree()), label='R-Value', shrink=0.75)
    plt.clim(vmin=-0.5, vmax=1)
    plt.text(0.95,0.95,months[i-1],horizontalalignment='center', verticalalignment='center', transform = ax.transAxes, size= 'xx-large')
    plt.pause(0.5)
    plt.show()

# %%
# figure = plt.figure(figsize=(18,10))
# ax = figure.add_subplot(1,1,1, projection=crs.Mercator())
# ax.add_feature(cfeature.COASTLINE)
# ax.add_feature(cfeature.STATES)
#     # Zoom in on the US by setting longitude/latitude parameters
# ax.set_extent(
#     [-130, # minimum latitude
#         -60, # min longitude
#         24, # max latitude
#         52 # max longitude
#     ],
# crs=crs.PlateCarree()
#     )
# display.clear_output(wait=True)
# plt.scatter(x=dflist['Longitude'], y=dflist['Latitude'], c = dflist.iloc[:, 3+8], s=250, alpha=1, cmap = 'hot', transform = crs.PlateCarree())
# plt.colorbar(plt.scatter(x=dflist['Longitude'], y=dflist['Latitude'], c = dflist.iloc[:, 3+8], s=250, alpha=1, cmap = 'hot', transform = crs.PlateCarree()))
# plt.text(0.95,0.95,months[8-1],horizontalalignment='center', verticalalignment='center', transform = ax.transAxes, size= 'x-large')
# plt.pause(0.5)
# plt.show()

# %%
# dflist.iloc[:, 3+8].sort_values()

# %%
# geolocator.geocode('Birmingham, AL')
# Out:
# Location(Birmingham, Jefferson County, Alabama, 35202, United States, (33.5206824, -86.8024326, 0.0))

# %%
# df[(df['City']=='Phoenix') & (df['Country']=='US')]['State'].unique()
# Out:
# array(['Arizona'], dtype=object)
